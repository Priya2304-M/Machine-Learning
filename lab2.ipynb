# %%
import pandas as pd
import matplotlib.pyplot as plt
# Load the CSV file
df = pd.read_csv('student_data.csv')

# View the first 5 rows of your data
print(df.head())
# Out:
#    RollNo   Name Gender  Attendance  InternalMarks  Externalmarks
# 0     101   Ravi      M          85             32             55
# 1     102  Priya      F          92             38             58
# 2     103  Kiran      M          78             28             45
# 3     104    Anu      F          95             40             60
# 4     105   Sita      F          88             35             54

# %%
#Task-A
print("first five records")
print(df.head())
# Out:
# first five records
#    RollNo   Name Gender  Attendance  InternalMarks  Externalmarks
# 0     101   Ravi      M          85             32             55
# 1     102  Priya      F          92             38             58
# 2     103  Kiran      M          78             28             45
# 3     104    Anu      F          95             40             60
# 4     105   Sita      F          88             35             54

# %%
#2
print("last five records")
print(df.tail())
# Out:
# last five records
#    RollNo     Name Gender  Attendance  InternalMarks  Externalmarks
# 5     106      Raj      M          70             25             40
# 6     107    Divya      F          90             37             57
# 7     108     Arun      M          82             30             48
# 8     109  Keerthi      F          96             39             59
# 9     110   Naveen      M          75             27             44

# %%
#3
print("total no of (Rows,Columns):")
print(df.shape)
# Out:
# total no of (Rows,Columns):
# (10, 6)

# %%
print("Columns:")
print(df.columns)
# Out:
# Columns:
# Index(['RollNo', 'Name', 'Gender', 'Attendance', 'InternalMarks',
#        'Externalmarks'],
#       dtype='object')

# %%
print("DataTypes:")
print(df.dtypes)
# Out:
# DataTypes:
# RollNo            int64
# Name             object
# Gender           object
# Attendance        int64
# InternalMarks     int64
# Externalmarks     int64
# dtype: object

# %%
print("dataset information")
print(df.info())
# Out:
# dataset information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   RollNo         10 non-null     int64
#  1   Name           10 non-null     object
#  2   Gender         10 non-null     object
#  3   Attendance     10 non-null     int64
#  4   InternalMarks  10 non-null     int64
#  5   Externalmarks  10 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 472.0+ bytes
# None

# %%
#Task-B
print("Mean Attendance:")
print(df['Attendance'].mean())
# Out:
# Mean Attendance:
# 85.1

# %%
print("Average Internal Marks:")
print(df['InternalMarks'].mean())
# Out:
# Average Internal Marks:
# 33.1

# %%
print("Average External Marks:")
print(df['Externalmarks'].max())
# Out:
# Average External Marks:
# 60

# %%
print("Maximum Internal Marks:")
print(df['InternalMarks'].max())
# Out:
# Maximum Internal Marks:
# 40

# %%
print("Minimum Internal Marks:")
print(df['InternalMarks'].min())
# Out:
# Minimum Internal Marks:
# 25

# %%
print("Maximum External Marks:")
print(df['Externalmarks'].max())
# Out:
# Maximum External Marks:
# 60

# %%
print("Minimum External Marks:")
print(df['Externalmarks'].min())
# Out:
# Minimum External Marks:
# 40

# %%
print("Standard Deviation internal marks:")
print(df['InternalMarks'].std())
# Out:
# Standard Deviation internal marks:
# 5.425249610233001

# %%
print("Summary Statistics:")
print(df.describe())
# Out:
# Summary Statistics:
#           RollNo  Attendance  InternalMarks  Externalmarks
# count   10.00000   10.000000       10.00000      10.000000
# mean   105.50000   85.100000       33.10000      52.000000
# std      3.02765    8.736259        5.42525       7.149204
# min    101.00000   70.000000       25.00000      40.000000
# 25%    103.25000   79.000000       28.50000      45.750000
# 50%    105.50000   86.500000       33.50000      54.500000
# 75%    107.75000   91.500000       37.75000      57.750000
# max    110.00000   96.000000       40.00000      60.000000

# %%
#task-C
df['TotalMarks'] = df['InternalMarks'] + df['Externalmarks']

# %%
df['Percentage'] = (df['TotalMarks'] / 100) * 100

# %%
print("Updated DataFrame:")
print(df)
# Out:
# Updated DataFrame:
#    RollNo     Name Gender  Attendance  InternalMarks  Externalmarks  \
# 0     101     Ravi      M          85             32             55
# 1     102    Priya      F          92             38             58
# 2     103    Kiran      M          78             28             45
# 3     104      Anu      F          95             40             60
# 4     105     Sita      F          88             35             54
# 5     106      Raj      M          70             25             40
# 6     107    Divya      F          90             37             57
# 7     108     Arun      M          82             30             48
# 8     109  Keerthi      F          96             39             59
# 9     110   Naveen      M          75             27             44
#
#    TotalMarks  Percentage
# 0          87        87.0
# 1          96        96.0
# 2          73        73.0
# 3         100       100.0
# 4          89        89.0
# 5          65        65.0
# ...

# %%
#task-D
print("Students with Attendnce > 90%:")
print(df[df['Attendance'] > 90])
# Out:
# Students with Attendnce > 90%:
#    RollNo     Name Gender  Attendance  InternalMarks  Externalmarks  \
# 1     102    Priya      F          92             38             58
# 3     104      Anu      F          95             40             60
# 8     109  Keerthi      F          96             39             59
#
#    TotalMarks  Percentage
# 1          96        96.0
# 3         100       100.0
# 8          98        98.0

# %%
print("Students with total marks > 90:")
print(df[df['TotalMarks'] > 90])
# Out:
# Students with total marks > 90:
#    RollNo     Name Gender  Attendance  InternalMarks  Externalmarks  \
# 1     102    Priya      F          92             38             58
# 3     104      Anu      F          95             40             60
# 6     107    Divya      F          90             37             57
# 8     109  Keerthi      F          96             39             59
#
#    TotalMarks  Percentage
# 1          96        96.0
# 3         100       100.0
# 6          94        94.0
# 8          98        98.0

# %%
print("Female Students:")
print(df[df['Gender'] == 'Female'])
# Out:
# Female Students:
# Empty DataFrame
# Columns: [RollNo, Name, Gender, Attendance, InternalMarks, Externalmarks, TotalMarks, Percentage]
# Index: []

# %%
print("Male Students:")
print(df[df['Gender'] == 'Male'])
# Out:
# Male Students:
# Empty DataFrame
# Columns: [RollNo, Name, Gender, Attendance, InternalMarks, Externalmarks, TotalMarks, Percentage]
# Index: []

# %%
print("Students with ExternalMarks < 50:")
print(df[df['Externalmarks'] < 50])
# Out:
# Students with ExternalMarks < 50:
#    RollNo    Name Gender  Attendance  InternalMarks  Externalmarks  \
# 2     103   Kiran      M          78             28             45
# 5     106     Raj      M          70             25             40
# 7     108    Arun      M          82             30             48
# 9     110  Naveen      M          75             27             44
#
#    TotalMarks  Percentage
# 2          73        73.0
# 5          65        65.0
# 7          78        78.0
# 9          71        71.0

# %%
#Task-E
print("Student with Highest TotalMarks:")
print(df.loc[df['TotalMarks'].idxmax()])
# Out:
# Student with Highest TotalMarks:
# RollNo             104
# Name               Anu
# Gender               F
# Attendance          95
# InternalMarks       40
# Externalmarks       60
# TotalMarks         100
# Percentage       100.0
# Name: 3, dtype: object

# %%
print("Student with Lowest TotalMarks:")
print(df.loc[df['TotalMarks'].idxmin()])
# Out:
# Student with Lowest TotalMarks:
# RollNo            106
# Name              Raj
# Gender              M
# Attendance         70
# InternalMarks      25
# Externalmarks      40
# TotalMarks         65
# Percentage       65.0
# Name: 5, dtype: object

# %%
print("Top three TotalMarks:")
print(df.nlargest(3,'TotalMarks'))
# Out:
# Top three TotalMarks:
#    RollNo     Name Gender  Attendance  InternalMarks  Externalmarks  \
# 3     104      Anu      F          95             40             60
# 8     109  Keerthi      F          96             39             59
# 1     102    Priya      F          92             38             58
#
#    TotalMarks  Percentage
# 3         100       100.0
# 8          98        98.0
# 1          96        96.0

# %%
print("Bottom three TotalMarks:")
print(df.nsmallest(3,'TotalMarks'))
# Out:
# Bottom three TotalMarks:
#    RollNo    Name Gender  Attendance  InternalMarks  Externalmarks  \
# 5     106     Raj      M          70             25             40
# 9     110  Naveen      M          75             27             44
# 2     103   Kiran      M          78             28             45
#
#    TotalMarks  Percentage
# 5          65        65.0
# 9          71        71.0
# 2          73        73.0

# %%
print("Number of students above class average:")
print(len(df[df['TotalMarks'] > avg_marks]))
# Out:
# Number of students above class average:
# 6

# %%
print("Average of Male Students TotalMarks:")
print(df[df['Gender']=='Male']['TotalMarks'].mean())
# Out:
# Average of Male Students TotalMarks:
# nan

# %%
print("Average of Female Students TotalMarks:")
print(df[df['Gender']== 'Female']['TotalMarks'].mean())
# Out:
# Average of Female Students TotalMarks:
# nan

# %%
print("Average Attendance of Male and Female students:")
print(df.groupby('Gender')['Attendance'].mean())
# Out:
# Average Attendance of Male and Female students:
# Gender
# F    92.2
# M    78.0
# Name: Attendance, dtype: float64

# %%
#Task-G
plt.figure(figsize=(10,5))
plt.bar(df['Name'],df['TotalMarks'])
plt.title('Total Marks of Students')
plt.xlabel('Students')
plt.ylabel('TotalMarks')
plt.show()

# %%
plt.hist(df['Attendance'], bins=10)
plt.xlabel('Attendance')
plt.ylabel('Frequency')
plt.title('Attendance Distribution')
plt.show()
